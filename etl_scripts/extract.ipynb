# %%
import pandas as pd

# %%
# read the raw data into a dataframe
raw_df = pd.read_csv("raw_data.csv")
raw_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# check df shape so that it matches the raw_data.csv: 1500 rows (without the headers) + 8 columns
raw_df.shape
# Out:
# (1500, 8)

# %%
# check data types of columns to see if there's anything weird
raw_df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# check for missing values
raw_df.isna().sum()
# Out:
# InvoiceNo       0
# StockCode       0
# Description     1
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID     58
# Country         0
# dtype: int64

# %%
# check for duplicates
raw_df[raw_df.duplicated()]
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 517     536409     21866          UNION JACK FLAG LUGGAGE TAG         1
# 527     536409     22866        HAND WARMER SCOTTY DOG DESIGN         1
# 537     536409     22900      SET 2 TEA TOWELS I LOVE LONDON          1
# 539     536409     22111         SCOTTIE DOG HOT WATER BOTTLE         1
# 555     536412     22327    ROUND SNACK BOXES SET OF 4 SKULLS         1
# 587     536412     22273                 FELTCRAFT DOLL MOLLY         1
# 589     536412     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         1
# 594     536412     22141       CHRISTMAS CRAFT TREE TOP ANGEL         1
# 598     536412     21448            12 DAISY PEGS IN WOOD BOX         1
# 600     536412     22569          FELTCRAFT CUSHION BUTTERFLY         2
# 601     536412     21448            12 DAISY PEGS IN WOOD BOX         2
# 604     536412     21448            12 DAISY PEGS IN WOOD BOX         2
# ...

# %%
# count how many duplicate rows there are:
raw_df.duplicated().sum()
# Out:
# np.int64(36)

# %%
# NOTICE (to be done in 'transformation'): 
# 1) a lot of generic 'object' types. MUST CHANGE THEM
# 2) customerID is float. CHANGE TO INT
# 3) InvoiceDate is object. CHANGE TO datetime64[ns]
# 4) 1 missing description and 58 missing customerID's 
# 5) There are 36 duplicate rows (they exist at least two times). drop them in transform (use raw_df.drop_duplicates())

# %%
CREATE FILE WITH THE ABOVE INFO
