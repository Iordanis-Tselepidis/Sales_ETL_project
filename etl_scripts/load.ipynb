# %%
import pandas as pd
import psycopg2
import os
from sqlalchemy import create_engine
from urllib.parse import quote
from dotenv import load_dotenv
from sqlalchemy import text

# %%
data = pd.read_csv("clean_data.csv")
data
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 1401    536542     20711                      JUMBO BAG TOYS         20
# 1402    536542     20713                       JUMBO BAG OWLS        30
# 1403    536542    85123A   WHITE HANGING HEART T-LIGHT HOLDER        32
# 1404   C536543     22632            HAND WARMER RED RETROSPOT         1
# 1405   C536543     22355            CHARLOTTE BAG SUKI DESIGN         2
#
#               InvoiceDate  UnitPrice  TotalAmount  CustomerID         Country
# 0     2010-12-01 08:26:00       2.55        15.30       17850  United Kingdom
# 1     2010-12-01 08:26:00       3.39        20.34       17850  United Kingdom
# 2     2010-12-01 08:26:00       2.75        22.00       17850  United Kingdom
# 3     2010-12-01 08:26:00       3.39        20.34       17850  United Kingdom
# 4     2010-12-01 08:26:00       3.39        20.34       17850  United Kingdom
# ...                   ...        ...          ...         ...             ...
# 1401  2010-12-01 14:11:00       1.95        39.00       16456  United Kingdom
# 1402  2010-12-01 14:11:00       1.95        58.50       16456  United Kingdom
# 1403  2010-12-01 14:11:00       2.95        94.40       16456  United Kingdom
# 1404  2010-12-01 14:30:00       2.10         2.10       17841  United Kingdom
# 1405  2010-12-01 14:30:00       0.85         1.70       17841  United Kingdom
#
# [1406 rows x 9 columns]

# %%
load_dotenv("../secret.env")
password = os.getenv("DB_PASSWORD")

# %%
encoded_password = quote(password)
engine = create_engine(
    f"postgresql+psycopg2://postgres:{encoded_password}@localhost:5432/SalesDB"
)
con = engine.connect()

# %%
sql = """
  create table if not exists sales (
  InvoiceNo INT,
  StockCode VARCHAR(155),
  Description VARCHAR(155),
  Quantity INT,
  InvoiceDate TIMESTAMP,
  UnitPrice NUMERIC(10,2),
  TotalAmount NUMERIC(10,2),
  CustomerID INT,
  Country VARCHAR(155)
);
"""

# %%
with engine.connect().execution_options(autocommit=True) as conn:
    query = conn.execute(text(sql))

# %%
with engine.connect().execution_options(autocommit=True) as conn:
    data.to_sql('sales', con=conn, if_exists='append', index= False)
